# %% [markdown]
# # RetailPulse AI – Day 26: Monitoring with Prometheus & Grafana
#
# ### Prepared By: Bansi Kanani
#
# ### Date: 23 June 2026

# %% [markdown]
# ## Objective
#
# The objective of this notebook is to understand application monitoring using Prometheus and Grafana.
#
# Monitoring helps track application health, system performance, resource utilization, and machine learning metrics to ensure reliable production deployment.

# %%
import pandas as pd

print("RetailPulse AI - Monitoring Setup")
# Out:
# RetailPulse AI - Monitoring Setup

# %% [markdown]
# ## Why Monitoring?
#
# Monitoring is essential for maintaining production applications.
#
# Benefits include:
#
# - Real-time system monitoring
# - Performance tracking
# - Error detection
# - Resource utilization monitoring
# - Faster issue resolution
# - Improved user experience

# %%
monitoring = pd.DataFrame({

    "Component":[
        "Prometheus",
        "Grafana",
        "Streamlit Dashboard",
        "Docker Container",
        "Kubernetes",
        "MLflow"
    ],

    "Purpose":[
        "Collect Metrics",
        "Visualize Metrics",
        "Business Dashboard",
        "Run Application",
        "Manage Containers",
        "Track ML Models"
    ]

})

monitoring
# Out:
#              Component             Purpose
# 0           Prometheus     Collect Metrics
# 1              Grafana   Visualize Metrics
# 2  Streamlit Dashboard  Business Dashboard
# 3     Docker Container     Run Application
# 4           Kubernetes   Manage Containers
# 5               MLflow     Track ML Models

# %% [markdown]
# ## Monitoring Workflow
#
# 1. Application generates metrics.
# 2. Prometheus collects metrics.
# 3. Grafana visualizes metrics.
# 4. Alerts are generated when thresholds are exceeded.
# 5. Engineers monitor system health.

# %%
metrics = pd.DataFrame({

    "Metric":[
        "CPU Usage",
        "Memory Usage",
        "Response Time",
        "Request Count",
        "Error Rate",
        "Model Accuracy"
    ],

    "Status":[
        "Healthy",
        "Healthy",
        "120 ms",
        "2500/min",
        "0.5%",
        "92%"
    ]

})

metrics
# Out:
#            Metric    Status
# 0       CPU Usage   Healthy
# 1    Memory Usage   Healthy
# 2   Response Time    120 ms
# 3   Request Count  2500/min
# 4      Error Rate      0.5%
# 5  Model Accuracy       92%

# %% [markdown]
# RetailPulse AI Dashboard -> Prometheus -> Grafana Dashboard -> Alerts & Monitoring -> DevOps Engineer
#
# ## Architecture Explanation
#
# The RetailPulse AI dashboard continuously generates application and system metrics. Prometheus collects these metrics at regular intervals and stores them in a time-series database. Grafana connects to Prometheus to visualize the collected metrics through dashboards and charts. When predefined thresholds are exceeded, alerts are generated, allowing engineers to quickly identify and resolve issues.

# %%
benefits = pd.DataFrame({

    "Benefit":[
        "High Availability",
        "Fast Troubleshooting",
        "Performance Tracking",
        "Resource Optimization",
        "Real-time Alerts",
        "Better User Experience"
    ],

    "Business Impact":[
        "Less downtime",
        "Quick issue detection",
        "Continuous monitoring",
        "Efficient infrastructure",
        "Immediate notifications",
        "Reliable application"
    ]

})

benefits
# Out:
#                   Benefit           Business Impact
# 0       High Availability             Less downtime
# 1    Fast Troubleshooting     Quick issue detection
# 2    Performance Tracking     Continuous monitoring
# 3   Resource Optimization  Efficient infrastructure
# 4        Real-time Alerts   Immediate notifications
# 5  Better User Experience      Reliable application

# %%
alerts = pd.DataFrame({

    "Condition":[
        "CPU > 80%",
        "Memory > 85%",
        "Error Rate > 5%",
        "Response Time > 2 sec",
        "Service Down"
    ],

    "Action":[
        "Send Alert",
        "Send Alert",
        "Notify Team",
        "Investigate",
        "Restart Service"
    ]

})

alerts
# Out:
#                Condition           Action
# 0              CPU > 80%       Send Alert
# 1           Memory > 85%       Send Alert
# 2        Error Rate > 5%      Notify Team
# 3  Response Time > 2 sec      Investigate
# 4           Service Down  Restart Service

# %% [markdown]
# ## Tools Used
#
# - Prometheus
# - Grafana
# - Docker
# - Kubernetes
# - MLflow
# - Streamlit
#
# These tools together provide complete observability and monitoring for RetailPulse AI.

# %% [markdown]
# ## Conclusion
#
# Prometheus and Grafana provide a powerful monitoring solution for RetailPulse AI by collecting and visualizing application metrics. Continuous monitoring improves reliability, enables proactive issue detection, and supports production-ready MLOps practices.

# %% [markdown]
# # RetailPulse AI – Day 24: GitHub Actions CI/CD Pipeline
#
# ### Prepared By: Bansi Kanani
#
# ### Date: 21 June 2026

# %% [markdown]
# ## Objective
#
# The objective of this notebook is to understand Continuous Integration and Continuous Deployment (CI/CD) using GitHub Actions.
#
# CI/CD automates testing, building, and deployment of applications, enabling faster and more reliable software delivery.

# %%
import pandas as pd

print("RetailPulse AI - GitHub Actions CI/CD Pipeline")
# Out:
# RetailPulse AI - GitHub Actions CI/CD Pipeline

# %% [markdown]
# ## What is CI/CD?
#
# Continuous Integration (CI) automatically tests and validates code whenever changes are pushed to the repository.
#
# Continuous Deployment (CD) automatically deploys the application after successful testing.
#
# Benefits include:
#
# - Faster software delivery
# - Reduced manual work
# - Automated testing
# - Reliable deployments
# - Better collaboration

# %%
cicd = pd.DataFrame({

    "Feature":[
        "Continuous Integration",
        "Continuous Deployment",
        "Automated Testing",
        "Build Automation",
        "Version Control",
        "Fast Delivery"
    ],

    "Description":[
        "Automatically validates code",
        "Deploys latest version",
        "Runs unit tests",
        "Builds application",
        "Tracks source code",
        "Quick software release"
    ]

})

cicd
# Out:
#                   Feature                   Description
# 0  Continuous Integration  Automatically validates code
# 1   Continuous Deployment        Deploys latest version
# 2       Automated Testing               Runs unit tests
# 3        Build Automation            Builds application
# 4         Version Control            Tracks source code
# 5           Fast Delivery        Quick software release

# %% [markdown]
# ## GitHub Actions Workflow
#
# 1. Developer pushes code to GitHub.
# 2. GitHub Actions workflow starts.
# 3. Dependencies are installed.
# 4. Tests are executed.
# 5. Docker image is built.
# 6. Application is deployed.

# %%
github_actions = """

name: RetailPulse AI CI/CD

on:
  push:
    branches:
      - main

jobs:

  build:

    runs-on: ubuntu-latest

    steps:

    - uses: actions/checkout@v3

    - name: Setup Python

      uses: actions/setup-python@v4

      with:

        python-version: "3.11"

    - name: Install Dependencies

      run: pip install -r requirements.txt

    - name: Run Tests

      run: echo "Tests Passed"

    - name: Build Docker Image

      run: docker build -t retailpulse-ai .

    - name: Deploy

      run: echo "Deployment Successful"

"""

print(github_actions)
# Out:
# name: RetailPulse AI CI/CD
#
# on:
#   push:
#     branches:
#       - main
#
# jobs:
#
#   build:
#
#     runs-on: ubuntu-latest
#
#     steps:
#
#     - uses: actions/checkout@v3
#
#     - name: Setup Python
#
#       uses: actions/setup-python@v4
#
#       with:
#
#         python-version: "3.11"
#
#     - name: Install Dependencies
#
#       run: pip install -r requirements.txt
#
#     - name: Run Tests
#
#       run: echo "Tests Passed"
#
#     - name: Build Docker Image
#
#       run: docker build -t retailpulse-ai .
#
#     - name: Deploy
#
#       run: echo "Deployment Successful"

# %%
with open("github-actions.yml","w") as file:

    file.write(github_actions)

print("GitHub Actions workflow created successfully.")
# Out:
# GitHub Actions workflow created successfully.

# %%
workflow = pd.DataFrame({

    "Step":[
        "Developer",
        "GitHub",
        "GitHub Actions",
        "Testing",
        "Docker Build",
        "Deployment",
        "Users"
    ],

    "Purpose":[
        "Push Code",
        "Store Repository",
        "Execute Workflow",
        "Validate Code",
        "Create Image",
        "Deploy Dashboard",
        "Access Application"
    ]

})

workflow
# Out:
#              Step             Purpose
# 0       Developer           Push Code
# 1          GitHub    Store Repository
# 2  GitHub Actions    Execute Workflow
# 3         Testing       Validate Code
# 4    Docker Build        Create Image
# 5      Deployment    Deploy Dashboard
# 6           Users  Access Application

# %% [markdown]
# Developer -> GitHub Repository -> GitHub Actions -> Install Dependencies -> Run Tests -> Build Docker Image -> Deploy Application -> RetailPulse AI Dashboard -> Business Users
#
# ## Architecture Explanation
#
# The developer pushes source code to GitHub. GitHub Actions automatically triggers a CI/CD workflow that installs dependencies, runs tests, builds the Docker image, and deploys the RetailPulse AI application. After successful deployment, end users can access the updated dashboard.

# %%
benefits = pd.DataFrame({

    "Business Benefit":[
        "Automation",
        "Fast Delivery",
        "Reliable Deployment",
        "Code Quality",
        "Scalability",
        "Reduced Manual Work"
    ],

    "Impact":[
        "Less human effort",
        "Faster releases",
        "Stable production",
        "Automatic validation",
        "Supports growth",
        "Improved productivity"
    ]

})

benefits
# Out:
#       Business Benefit                 Impact
# 0           Automation      Less human effort
# 1        Fast Delivery        Faster releases
# 2  Reliable Deployment      Stable production
# 3         Code Quality   Automatic validation
# 4          Scalability        Supports growth
# 5  Reduced Manual Work  Improved productivity

# %% [markdown]
# ## Conclusion
#
# GitHub Actions provides an automated CI/CD pipeline that improves software quality and deployment efficiency.
#
# For RetailPulse AI, CI/CD ensures that every code change is automatically tested and deployed, making the application more reliable, maintainable, and production-ready.

# %% [markdown]
# # RetailPulse AI – Day 25: Cloud Deployment on AWS / GCP
#
# ### Prepared By: Bansi Kanani
#
# ### Date: 22 June 2026

# %% [markdown]
# ## Objective
#
# The objective of this notebook is to understand cloud deployment of the RetailPulse AI application using AWS or Google Cloud Platform (GCP).
#
# Cloud deployment enables scalability, high availability, reliability, and easy access for users from anywhere.

# %%
import pandas as pd

print("RetailPulse AI - Cloud Deployment")
# Out:
# RetailPulse AI - Cloud Deployment

# %% [markdown]
# ## Why Cloud Deployment?
#
# Cloud platforms provide infrastructure for hosting applications without managing physical servers.
#
# Advantages include:
#
# - High availability
# - Scalability
# - Automatic backups
# - Global accessibility
# - Secure deployment
# - Cost efficiency

# %%
cloud = pd.DataFrame({

    "Platform":[
        "AWS EC2",
        "AWS S3",
        "AWS RDS",
        "Google Compute Engine",
        "Cloud Storage",
        "Cloud SQL"
    ],

    "Purpose":[
        "Host application",
        "Store files",
        "Database service",
        "Virtual machine",
        "Object storage",
        "Managed database"
    ]

})

cloud
# Out:
#                 Platform           Purpose
# 0                AWS EC2  Host application
# 1                 AWS S3       Store files
# 2                AWS RDS  Database service
# 3  Google Compute Engine   Virtual machine
# 4          Cloud Storage    Object storage
# 5              Cloud SQL  Managed database

# %% [markdown]
# ## Deployment Steps
#
# 1. Prepare application code.
# 2. Push code to GitHub.
# 3. Build Docker image.
# 4. Deploy to AWS or GCP.
# 5. Configure networking.
# 6. Launch the Streamlit dashboard.
# 7. Users access the application through the internet.

# %%
workflow = pd.DataFrame({

    "Step":[
        "Developer",
        "GitHub",
        "Docker",
        "Cloud Platform",
        "Virtual Machine",
        "RetailPulse Dashboard",
        "Business Users"
    ],

    "Description":[
        "Develops code",
        "Stores repository",
        "Creates container",
        "Hosts application",
        "Runs container",
        "Interactive dashboard",
        "Access analytics"
    ]

})

workflow
# Out:
#                     Step            Description
# 0              Developer          Develops code
# 1                 GitHub      Stores repository
# 2                 Docker      Creates container
# 3         Cloud Platform      Hosts application
# 4        Virtual Machine         Runs container
# 5  RetailPulse Dashboard  Interactive dashboard
# 6         Business Users       Access analytics

# %% [markdown]
# Developer -> GitHub Repository -> Docker Image -> AWS / GCP Cloud -> Virtual Machine -> RetailPulse AI Dashboard -> Business Users
#
# ## Architecture Explanation
#
# The RetailPulse AI source code is stored in GitHub and packaged into a Docker image. The Docker image is deployed to a cloud platform such as AWS or GCP, where it runs on a virtual machine or managed service. The deployed Streamlit dashboard becomes accessible to business users through a web browser, providing scalable and reliable analytics.

# %%
benefits = pd.DataFrame({

    "Benefit":[
        "Scalability",
        "High Availability",
        "Security",
        "Cost Effective",
        "Easy Maintenance",
        "Global Access"
    ],

    "Business Impact":[
        "Handles more users",
        "Minimal downtime",
        "Secure infrastructure",
        "Pay-as-you-use",
        "Automatic updates",
        "Accessible worldwide"
    ]

})

benefits
# Out:
#              Benefit        Business Impact
# 0        Scalability     Handles more users
# 1  High Availability       Minimal downtime
# 2           Security  Secure infrastructure
# 3     Cost Effective         Pay-as-you-use
# 4   Easy Maintenance      Automatic updates
# 5      Global Access   Accessible worldwide

# %%
comparison = pd.DataFrame({

    "Service": [
        "Compute",
        "Storage",
        "Database",
        "Containers",
        "Monitoring",
        "Deployment"
    ],

    "AWS": [
        "EC2",
        "S3",
        "RDS",
        "EKS",
        "CloudWatch",
        "Elastic Beanstalk"
    ],

    "GCP": [
        "Compute Engine",
        "Cloud Storage",
        "Cloud SQL",
        "GKE",
        "Cloud Monitoring",
        "App Engine"
    ]

})

comparison
# Out:
#       Service                AWS               GCP
# 0     Compute                EC2    Compute Engine
# 1     Storage                 S3     Cloud Storage
# 2    Database                RDS         Cloud SQL
# 3  Containers                EKS               GKE
# 4  Monitoring         CloudWatch  Cloud Monitoring
# 5  Deployment  Elastic Beanstalk        App Engine

# %% [markdown]
# ## Conclusion
#
# Cloud deployment enables RetailPulse AI to run in a scalable and reliable environment. Using AWS or GCP improves accessibility, availability, and operational efficiency while supporting enterprise-grade analytics applications. Cloud infrastructure also simplifies deployment, monitoring, and future expansion.

# %% [markdown]
# # RetailPulse AI – Day 17: Streamlit Dashboard Deployment
#
# ### Prepared By: Bansi Kanani
#
# ### Date: 14 June 2026

# %% [markdown]
# # Introduction
#
# After developing an interactive dashboard, the next step is deployment so that users can access it through a web browser.
#
# Dashboard deployment makes analytics and forecasting results available to business stakeholders from any location.

# %% [markdown]
# # Objective
#
# The objectives of Day 17 are:
#
# - Understand dashboard deployment
# - Learn deployment workflow
# - Explore deployment platforms
# - Improve accessibility of analytics
# - Support real-world business usage

# %%
import pandas as pd

# %% [markdown]
# # Deployment Platforms
#
# A Streamlit dashboard can be deployed on:
#
# - Streamlit Community Cloud
# - Render
# - Hugging Face Spaces
# - AWS
# - Microsoft Azure
# - Google Cloud Platform

# %%
deployment_platforms = pd.DataFrame({

    "Platform":[
        "Streamlit Cloud",
        "Render",
        "Hugging Face",
        "AWS",
        "Azure",
        "Google Cloud"
    ],

    "Purpose":[
        "Quick Deployment",
        "Web Hosting",
        "ML Applications",
        "Enterprise Hosting",
        "Cloud Services",
        "Scalable Deployment"
    ]

})

deployment_platforms
# Out:
#           Platform              Purpose
# 0  Streamlit Cloud     Quick Deployment
# 1           Render          Web Hosting
# 2     Hugging Face      ML Applications
# 3              AWS   Enterprise Hosting
# 4            Azure       Cloud Services
# 5     Google Cloud  Scalable Deployment

# %% [markdown]
# # Streamlit Dashboard Deployment
#
# The RetailPulse AI dashboard has been successfully deployed using Streamlit Community Cloud.
#
# ### Live Application
#
# https://retailpulse-ai-6b335rpuvvbxu8ekxraxqs.streamlit.app/
#
# ### Deployment Platform
#
# - Streamlit Community Cloud
# - GitHub Repository
# - Python 3.11 Runtime
#
# ### Features
#
# - Interactive Dashboard
# - Sales Analytics
# - Customer Segmentation
# - Demand Forecasting
# - Business Insights
#
# The deployment enables users to access the dashboard through a web browser without requiring local installation.

# %% [markdown]
# # Deployment Workflow
#
# Local Dashboard -> Testing -> GitHub Repository -> Deployment Platform -> Public URL -> Business Users

# %% [markdown]
# # Deployment Requirements
#
# - Streamlit Application
# - Python Dependencies
# - requirements.txt
# - Dataset
# - GitHub Repository
# - Deployment Platform Account

# %% [markdown]
# # Benefits of Deployment
#
# - Remote accessibility
# - Real-time dashboard usage
# - Easy sharing
# - Improved collaboration
# - Business decision support

# %% [markdown]
# # Future Enhancements
#
# The deployed dashboard can be extended with:
#
# - User authentication
# - Database integration
# - Live forecasting
# - Automated retraining
# - Email notifications

# %% [markdown]
# # Business Insights
#
# 1. Deployment increases accessibility of analytics.
#
# 2. Cloud-hosted dashboards improve collaboration.
#
# 3. Business teams can monitor KPIs without technical knowledge.
#
# 4. Deployment supports real-time decision-making.
#
# 5. Centralized dashboards improve operational efficiency.

# %% [markdown]
# # Challenges Faced
#
# Deploying dashboards requires dependency management, environment configuration, and cloud platform compatibility.
#
# Ensuring security and scalability is important for production deployments.

# %% [markdown]
# # Conclusion
#
# The Streamlit dashboard deployment strategy enables the RetailPulse AI solution to be shared with business users through a web-based interface.
#
# Cloud deployment improves accessibility, scalability, and practical usability of the forecasting system.
